# %% [markdown]
# ## LSA 실습

# %% [markdown]
# ### 1. 환경설정

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 73.9 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import numpy as np
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.datasets import fetch_20newsgroups
from gensim import corpora, matutils
from gensim.models import TfidfModel
from gensim.models import lsimodel
import matplotlib.pyplot as plt
from pprint import pprint

# NLTK 데이터 다운로드
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %% [markdown]
# ### 2. 코퍼스 정의

# %%
# 데이터셋 로드
categories = ['alt.atheism', 'talk.religion.misc',
              'comp.graphics', 'sci.space']

newsgroups_train = fetch_20newsgroups(
    subset='train',
    categories=categories,
    remove=('headers', 'footers', 'quotes'),
    random_state=123
)

documents = newsgroups_train.data

print(f"전체 문서 수: {len(documents)}")
# Out:
# 전체 문서 수: 2034

# %%
# 불용어 및 lemmatizer 설정
stopwords_en = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# 텍스트 전처리 함수
def text_to_tokens(text):
    text = text.lower()  # 소문자 변환
    tokens = nltk.word_tokenize(text)  # 토큰화
    tokens = [lemmatizer.lemmatize(t) for t in tokens]  # 표제어 추출
    tokens = [t for t in tokens if t not in stopwords_en]  # 불용어 제거
    tokens = [t for t in tokens if re.fullmatch('[a-z]+', t)]  # 알파벳만 유지
    return tokens

# 문서 전처리
doc_tokenized = [text_to_tokens(doc) for doc in documents]
print(f"첫 번째 문서의 토큰 수: {len(doc_tokenized[0])}")
print(f"토큰 샘플: {doc_tokenized[0][:10]}")

# Gensim 사전 및 BoW 생성
dictionary = corpora.Dictionary(doc_tokenized)
bow_corpus = [dictionary.doc2bow(doc) for doc in doc_tokenized]

print(f"단어 수: {len(dictionary)}")
print(f"문서 수: {len(bow_corpus)}")
# Out:
# 첫 번째 문서의 토큰 수: 8
# 토큰 샘플: ['file', 'format', 'autodesk', 'animation', 'studio', 'available', 'thanks', 'gary']
# 단어 수: 19886
# 문서 수: 2034

# %% [markdown]
# ### 3. LSA 모델 적용 - TF-IDF 행렬
# * 코퍼스를 TF-IDF 행렬을 기반으로 셍성

# %%
tfidf_model = TfidfModel(bow_corpus, smartirs='nfc')
tfidf_corpus = tfidf_model[bow_corpus]

# %%
# 세 번째 문서에서 가장 빈도가 높은 단어 찾기
doc2_bow = bow_corpus[2]
most_frequent = max(doc2_bow, key=lambda x: x[1])  # (단어ID, 빈도) 중 빈도가 최대인 것
word_id, frequency = most_frequent
word = dictionary[word_id]

print(f"세 번째 문서에서 가장 많이 등장하는 단어: '{word}' ({frequency}번)")
# Out:
# 세 번째 문서에서 가장 많이 등장하는 단어: 'paintbrush' (3번)

# %%
tfidf_matrix = matutils.corpus2dense(tfidf_corpus, num_terms=len(dictionary)).transpose()
print(f"해당 단어의 인덱스: {word_id}")
print(f"해당 단어의 TF-IDF 값: {tfidf_matrix[2, word_id]:.4f}")
# Out:
# 해당 단어의 인덱스: 71
# 해당 단어의 TF-IDF 값: 0.6659

# %% [markdown]
# * TF-IDF 행렬을 토픽 수가 2개인 LSA 모델에 적용

# %%
# LSA(LSI) 모델 적용
lsi_model = lsimodel.LsiModel(corpus=tfidf_corpus, id2word=dictionary, num_topics=2, random_seed=123)

# %% [markdown]
# ### 4. 토픽별 단어 할당값

# %%
# 토픽별 단어 할당값 행렬
topic_word_assignment_mat = lsi_model.get_topics()
print("토픽별 단어 할당값의 행렬 표현:")
pprint(np.round(topic_word_assignment_mat, 3))

print("토픽별 중요한 단어 순서대로 표현:")
pprint(lsi_model.print_topics())
# Out:
# 토픽별 단어 할당값의 행렬 표현:
# array([[-0.019, -0.002, -0.044, ..., -0.   , -0.   , -0.   ],
#        [ 0.045,  0.009,  0.082, ...,  0.   ,  0.   ,  0.   ]])
# 토픽별 중요한 단어 순서대로 표현:
# [(0,
#   '-0.153*"wa" + -0.150*"god" + -0.140*"would" + -0.120*"one" + '
#   '-0.119*"people" + -0.108*"doe" + -0.107*"think" + -0.104*"space" + '
#   '-0.103*"know" + -0.096*"like"'),
#  (1,
#   '-0.274*"god" + 0.257*"file" + 0.190*"image" + 0.161*"thanks" + '
#   '0.152*"program" + 0.151*"format" + -0.140*"jesus" + 0.135*"graphic" + '
#   '-0.126*"christian" + 0.112*"color"')]

# %%
print(np.abs(topic_word_assignment_mat[1,:]))
# 가장 큰 값의 인덱스 도출
print("가장 큰 값을 가진 인덱스:",np.argmax(np.abs(topic_word_assignment_mat[1,:])))
# Out:
# [0.04542264 0.00859485 0.08229202 ... 0.00028875 0.00028875 0.00028875]
# 가장 큰 값을 가진 인덱스: 1128

# %%
print("첫번째 토픽의 가장 중요한 단어:", np.argmax(np.abs(topic_word_assignment_mat[1,:])))
print("인덱스 1128의 단어는", dictionary[1128])
print("첫번째 토픽의 인덱스 1128 단어의 할당값은", topic_word_assignment_mat[0,1128])
# Out:
# 첫번째 토픽의 가장 중요한 단어: 1128
# 인덱스 1128의 단어는 god
# 첫번째 토픽의 인덱스 1128 단어의 할당값은 -0.15018425421507628

# %%
# paintbrush단어의 인덱스 탐색
dictionary.token2id['paintbrush']
# Out:
# 71

# %%
topic_word_assignment_mat[1,71]
# Out:
# np.float64(0.0024979589585771697)

# %%
print("두번째 토픽의 paintbrush 단어 할당값:", topic_word_assignment_mat[1,dictionary.token2id['paintbrush']])
# Out:
# 두번째 토픽의 paintbrush 단어 할당값: 0.0024979589585771697

# %% [markdown]
# ### 5. 문서별 토픽 할당값

# %%
# 문서별 토픽 할당값
doc_topic_assignment = lsi_model[bow_corpus]
print("문서별 토픽 할당값의 간단한 표현:")
pprint(list(doc_topic_assignment))

# 문서별 토픽 할당값 행렬 표현
doc_topic_assignment_mat = np.zeros(shape=(len(doc_topic_assignment), lsi_model.num_topics), dtype=float)
for doc_idx, doc_topics in enumerate(doc_topic_assignment):
    for topic_idx, topic_weight in doc_topics:
        doc_topic_assignment_mat[doc_idx, topic_idx] = topic_weight

print("문서별 토픽 할당값의 행렬 표현:")
pprint(np.round(doc_topic_assignment_mat, 3))
# Out:
# 문서별 토픽 할당값의 간단한 표현:
# [[(np.int64(0), np.float64(-0.28369167989397437)),
#   (np.int64(1), np.float64(0.7299517305610559))],
#  [(np.int64(0), np.float64(-1.5388211894962367)),
#   (np.int64(1), np.float64(-0.07354219042247263))],
#  [(np.int64(0), np.float64(-0.497495193330542)),
#   (np.int64(1), np.float64(0.5448022315338422))],
#  [(np.int64(0), np.float64(-0.31155417456098927)),
#   (np.int64(1), np.float64(0.24358652120148303))],
#  [(np.int64(0), np.float64(-1.723297501973893)),
#   (np.int64(1), np.float64(-0.1299934863392989))],
#  [(np.int64(0), np.float64(-1.0671799088622724)),
#   (np.int64(1), np.float64(0.18622315402358436))],
#  [(np.int64(0), np.float64(-0.6982444334460911)),
#   (np.int64(1), np.float64(0.657912526303343))],
#  [(np.int64(0), np.float64(-0.23005339158759752)),
#   (np.int64(1), np.float64(-0.1313763835643121))],
#  [(np.int64(0), np.float64(-0.14750426715721404)),
#   (np.int64(1), np.float64(-0.021417091000079738))],
#  [(np.int64(0), np.float64(-2.9656096123311126)),
#   (np.int64(1), np.float64(0.8960059899087495))],
#  [(np.int64(0), np.float64(-0.7772196319548291)),
#   (np.int64(1), np.float64(-0.04964594499689981))],
#  [(np.int64(0), np.float64(-2.0551735551242056)),
#   (np.int64(1), np.float64(0.08356188993575794))],
#  [(np.int64(0), np.float64(-2.3194652720597704)),
#   (np.int64(1), np.float64(-0.45115810107776927))],
#  [(np.int64(0), np.float64(-8.017271826758193)),
#   (np.int64(1), np.float64(0.2275090292347775))],
#  [(np.int64(0), np.float64(-1.907639797234782)),
#   (np.int64(1), np.float64(0.5020465513753305))],
#  [(np.int64(0), np.float64(-6.399709889317301)),
#   (np.int64(1), np.float64(7.400151486746775))],
#  [(np.int64(0), np.float64(-0.11214757637316684)),
#   (np.int64(1), np.float64(-0.07036688930888615))],
#  [(np.int64(0), np.float64(-0.29458301560937183)),
#   (np.int64(1), np.float64(0.010447789296780814))],
#  [(np.int64(0), np.float64(-1.7306349957486078)),
#   (np.int64(1), np.float64(1.4171905637937223))],
#  [(np.int64(0), np.float64(-0.8853258980246479)),
#   (np.int64(1), np.float64(0.5532446809266341))],
#  [(np.int64(0), np.float64(-2.481163740040259)),
#   (np.int64(1), np.float64(-0.20686010157368284))],
#  [(np.int64(0), np.float64(-1.7089448373827958)),
#   (np.int64(1), np.float64(-0.7021073411927032))],
#  [(np.int64(0), np.float64(-1.2748037274344461)),
#   (np.int64(1), np.float64(0.956686903939036))],
#  [(np.int64(0), np.float64(-0.45855997998532044)),
#   (np.int64(1), np.float64(-0.04727347520843829))],
#  [(np.int64(0), np.float64(-2.3035148518150113)),
#   (np.int64(1), np.float64(-0.24593110068819748))],
#  [(np.int64(0), np.float64(-8.270464521289087)),
#   (np.int64(1), np.float64(2.2477222118652143))],
#  [(np.int64(0), np.float64(-0.7541349154548866)),
#   (np.int64(1), np.float64(0.09354370918570207))],
#  [(np.int64(0), np.float64(-2.3463406481433267)),
#   (np.int64(1), np.float64(0.31982848646287343))],
#  [(np.int64(0), np.float64(-1.0201474910878778)),
#   (np.int64(1), np.float64(0.051523408677607754))],
#  [(np.int64(0), np.float64(-0.5253074699324431)),
#   (np.int64(1), np.float64(0.5615202578632174))],
#  [(np.int64(0), np.float64(-8.365647723890824)),
#   (np.int64(1), np.float64(-3.489475164482003))],
#  [(np.int64(0), np.float64(-0.14764072629436545)),
#   (np.int64(1), np.float64(-0.07335381955090071))],
#  [(np.int64(0), np.float64(-0.5555849533168122)),
#   (np.int64(1), np.float64(-0.10117460269254328))],
#  [(np.int64(0), np.float64(-1.8469446224473374)),
#   (np.int64(1), np.float64(-0.23658299016597925))],
#  [(np.int64(0), np.float64(-0.23274679772356466)),
#   (np.int64(1), np.float64(-0.023393066266410096))],
#  [(np.int64(0), np.float64(-2.9253218801431085)),
#   (np.int64(1), np.float64(-0.08733253581354627))],
#  [(np.int64(0), np.float64(-0.00309046849979765)),
#   (np.int64(1), np.float64(0.001255572290694357))],
#  [(np.int64(0), np.float64(-0.7174806862456957)),
#   (np.int64(1), np.float64(-0.23314481008683))],
#  [(np.int64(0), np.float64(-1.2579671718864462)),
#   (np.int64(1), np.float64(0.7361308756475583))],
#  [(np.int64(0), np.float64(-1.2192174036024275)),
#   (np.int64(1), np.float64(-0.12785359575686414))],
#  [(np.int64(0), np.float64(-0.1312451816434928)),
#   (np.int64(1), np.float64(-0.08882746975198452))],
#  [(np.int64(0), np.float64(-2.024718802715973)),
#   (np.int64(1), np.float64(-0.320547899814177))],
#  [(np.int64(0), np.float64(-0.636454774472427)),
#   (np.int64(1), np.float64(-0.12527992263632473))],
#  [(np.int64(0), np.float64(-1.5686894631727568)),
#   (np.int64(1), np.float64(-0.6423173123051031))],
#  [(np.int64(0), np.float64(-4.410885742234176)),
#   (np.int64(1), np.float64(-1.6801041070462754))],
#  [(np.int64(0), np.float64(-2.1820661409301105)),
#   (np.int64(1), np.float64(-1.1684197233313158))],
#  [(np.int64(0), np.float64(-1.9034177418931932)),
#   (np.int64(1), np.float64(-0.6801983650230393))],
#  [(np.int64(0), np.float64(-0.298581655271408)),
#   (np.int64(1), np.float64(0.09379827670848466))],
#  [(np.int64(0), np.float64(-0.4891328968787029)),
#   (np.int64(1), np.float64(-0.5489584696853956))],
#  [(np.int64(0), np.float64(-1.522842067939268)),
#   (np.int64(1), np.float64(1.0954329766558577))],
#  [(np.int64(0), np.float64(-0.6129868802137125)),
#   (np.int64(1), np.float64(-0.328928788423473))],
#  [(np.int64(0), np.float64(-0.558017642382071)),
#   (np.int64(1), np.float64(0.3540267303976868))],
#  [(np.int64(0), np.float64(-0.7929944271339151)),
#   (np.int64(1), np.float64(-0.09758871659501477))],
#  [(np.int64(0), np.float64(-0.7347998821869319)),
#   (np.int64(1), np.float64(0.39188009086339975))],
#  [(np.int64(0), np.float64(-1.0947029577437848)),
#   (np.int64(1), np.float64(-0.2787843425364219))],
#  [],
#  [(np.int64(0), np.float64(-1.2361977632273733)),
#   (np.int64(1), np.float64(-0.8537019726244174))],
#  [(np.int64(0), np.float64(-1.7932685654441896)),
#   (np.int64(1), np.float64(1.920119084050318))],
#  [(np.int64(0), np.float64(-1.0646223784212547)),
#   (np.int64(1), np.float64(0.26508470599654327))],
#  [(np.int64(0), np.float64(-1.4597147632957694)),
#   (np.int64(1), np.float64(1.065088050858003))],
#  [(np.int64(0), np.float64(-1.4352623563670375)),
#   (np.int64(1), np.float64(0.14909446466130313))],
#  [(np.int64(0), np.float64(-0.9585403807810113)),
#   (np.int64(1), np.float64(0.1670469544739344))],
#  [(np.int64(0), np.float64(-3.883011243288641)),
#   (np.int64(1), np.float64(0.8490618149601291))],
#  [(np.int64(0), np.float64(-137.24140874848845)),
#   (np.int64(1), np.float64(139.42779555850777))],
#  [(np.int64(0), np.float64(-0.331183578553105)),
#   (np.int64(1), np.float64(-0.06240014350517332))],
#  [(np.int64(0), np.float64(-5.179350591408294)),
#   (np.int64(1), np.float64(-1.3123924183116116))],
#  [(np.int64(0), np.float64(-0.5021172082456856)),
#   (np.int64(1), np.float64(-0.08079601620586924))],
#  [(np.int64(0), np.float64(-1.869244904600781)),
#   (np.int64(1), np.float64(-0.32043402379511854))],
#  [(np.int64(0), np.float64(-0.5211892210827513)),
#   (np.int64(1), np.float64(0.8167681574136882))],
#  [(np.int64(0), np.float64(-0.1860077809409675)),
#   (np.int64(1), np.float64(-0.060761609137333555))],
#  [(np.int64(0), np.float64(-0.3873215343202903)),
#   (np.int64(1), np.float64(0.0549878918950645))],
#  [(np.int64(0), np.float64(-4.983452370275534)),
#   (np.int64(1), np.float64(0.26701617188188054))],
#  [(np.int64(0), np.float64(-5.596082077553816)),
#   (np.int64(1), np.float64(2.6450492421842755))],
#  [(np.int64(0), np.float64(-0.8294011314616478)),
#   (np.int64(1), np.float64(-0.14285034009192576))],
#  [(np.int64(0), np.float64(-1.2771780519562175)),
#   (np.int64(1), np.float64(0.0021868262214265015))],
#  [(np.int64(0), np.float64(-1.2147742529258811)),
#   (np.int64(1), np.float64(-0.32670263422883655))],
#  [(np.int64(0), np.float64(-1.2588363168293877)),
#   (np.int64(1), np.float64(0.12288895508864892))],
#  [(np.int64(0), np.float64(-1.0015707131769809)),
#   (np.int64(1), np.float64(-0.28392489132345994))],
#  [(np.int64(0), np.float64(-12.084280676834599)),
#   (np.int64(1), np.float64(-4.0443698728603925))],
#  [(np.int64(0), np.float64(-3.059143633065112)),
#   (np.int64(1), np.float64(-0.42211523480016955))],
#  [(np.int64(0), np.float64(-1.1426931608277762)),
#   (np.int64(1), np.float64(-0.3360512687384981))],
#  [(np.int64(0), np.float64(-9.326658182242547)),
#   (np.int64(1), np.float64(-6.744683613313132))],
#  [(np.int64(0), np.float64(-1.23887353135038)),
#   (np.int64(1), np.float64(0.7332074483194593))],
#  [(np.int64(0), np.float64(-2.1411211907538767)),
#   (np.int64(1), np.float64(0.09612290938971055))],
#  [(np.int64(0), np.float64(-3.424362921914452)),
#   (np.int64(1), np.float64(-2.7598748647947153))],
#  [(np.int64(0), np.float64(-0.7881153906567978)),
#   (np.int64(1), np.float64(-0.22787195411039898))],
#  [(np.int64(0), np.float64(-6.285153114501033)),
#   (np.int64(1), np.float64(0.45412244147989805))],
#  [(np.int64(0), np.float64(-0.14736123483818592)),
#   (np.int64(1), np.float64(0.05303554258284355))],
#  [(np.int64(0), np.float64(-0.641754275908131)),
#   (np.int64(1), np.float64(0.4309238852850445))],
#  [(np.int64(0), np.float64(-4.278774753210779)),
#   (np.int64(1), np.float64(5.892538917253312))],
#  [(np.int64(0), np.float64(-0.7979705434903391)),
#   (np.int64(1), np.float64(-0.2703475345683491))],
#  [(np.int64(0), np.float64(-2.525941540860447)),
#   (np.int64(1), np.float64(0.6466999287030359))],
#  [(np.int64(0), np.float64(-2.5869496435882025)),
#   (np.int64(1), np.float64(-0.6537240096044247))],
#  [(np.int64(0), np.float64(-0.5466176646335995)),
#   (np.int64(1), np.float64(0.008745913683834122))],
#  [(np.int64(0), np.float64(-0.6820817032502731)),
#   (np.int64(1), np.float64(-0.19078170213741175))],
#  [(np.int64(0), np.float64(-1.1387800438804347)),
#   (np.int64(1), np.float64(1.2054900599118858))],
#  [(np.int64(0), np.float64(-1.8453147302310713)),
#   (np.int64(1), np.float64(2.3303664412240748))],
#  [(np.int64(0), np.float64(-1.3395813329149007)),
#   (np.int64(1), np.float64(0.0041019985969532324))],
#  [(np.int64(0), np.float64(-0.18371104235802244)),
#   (np.int64(1), np.float64(-0.09007958486935091))],
#  [(np.int64(0), np.float64(-0.031930704307976246)),
#   (np.int64(1), np.float64(0.006973024466413193))],
#  [(np.int64(0), np.float64(-0.17802499729094182)),
#   (np.int64(1), np.float64(-0.11694532932592719))],
#  [(np.int64(0), np.float64(-0.7215279058686527)),
#   (np.int64(1), np.float64(0.12933570576787945))],
#  [(np.int64(0), np.float64(-0.5932329656121393)),
#   (np.int64(1), np.float64(0.2504038719894694))],
#  [(np.int64(0), np.float64(-0.38537988252029015)),
#   (np.int64(1), np.float64(-0.011814369902263068))],
#  [(np.int64(0), np.float64(-4.888043380973731)),
#   (np.int64(1), np.float64(0.42700055508964496))],
#  [(np.int64(0), np.float64(-1.7404520491402067)),
#   (np.int64(1), np.float64(-0.945581693640783))],
#  [(np.int64(0), np.float64(-1.7089448373827958)),
#   (np.int64(1), np.float64(-0.7021073411927032))],
#  [(np.int64(0), np.float64(-4.142292013948614)),
#   (np.int64(1), np.float64(-2.961018359597732))],
#  [(np.int64(0), np.float64(-1.6494310546429292)),
#   (np.int64(1), np.float64(-1.2763633596332715))],
#  [(np.int64(0), np.float64(-3.8312664665702165)),
#   (np.int64(1), np.float64(0.6665715637680445))],
#  [(np.int64(0), np.float64(-0.9162688111206014)),
#   (np.int64(1), np.float64(-0.29041931883151034))],
#  [(np.int64(0), np.float64(-2.5116012061776587)),
#   (np.int64(1), np.float64(-1.065901017427834))],
#  [(np.int64(0), np.float64(-1.454999476382909)),
#   (np.int64(1), np.float64(-0.2673850123406952))],
#  [(np.int64(0), np.float64(-2.8506760257103965)),
#   (np.int64(1), np.float64(1.4924175194568063))],
#  [(np.int64(0), np.float64(-2.0665851898147425)),
#   (np.int64(1), np.float64(-0.7941836669799386))],
#  [(np.int64(0), np.float64(-5.386259749454163)),
#   (np.int64(1), np.float64(2.6647959515811914))],
#  [(np.int64(0), np.float64(-3.3726419500035845)),
#   (np.int64(1), np.float64(-1.2494872625995341))],
#  [(np.int64(0), np.float64(-3.1557388894446925)),
#   (np.int64(1), np.float64(-1.0962496748215316))],
#  [(np.int64(0), np.float64(-0.11315162180074494)),
#   (np.int64(1), np.float64(0.021614592752101827))],
#  [(np.int64(0), np.float64(-9.4243315584652)),
#   (np.int64(1), np.float64(-6.734450129482162))],
#  [(np.int64(0), np.float64(-0.3531108491829216)),
#   (np.int64(1), np.float64(0.017253025408593487))],
#  [(np.int64(0), np.float64(-0.973542148177812)),
#   (np.int64(1), np.float64(0.16082436616140228))],
#  [(np.int64(0), np.float64(-1.7521885022054633)),
#   (np.int64(1), np.float64(-0.6609678901458715))],
#  [(np.int64(0), np.float64(-1.529744477525321)),
#   (np.int64(1), np.float64(-0.1564031102848843))],
#  [(np.int64(0), np.float64(-0.5329363177710151)),
#   (np.int64(1), np.float64(0.6613529090611024))],
#  [(np.int64(0), np.float64(-0.7955995174346897)),
#   (np.int64(1), np.float64(1.1597165993184537))],
#  [(np.int64(0), np.float64(-0.6140248663307689)),
#   (np.int64(1), np.float64(0.2644202230552908))],
#  [(np.int64(0), np.float64(-2.136495201175536)),
#   (np.int64(1), np.float64(-0.10702886488967736))],
#  [(np.int64(0), np.float64(-2.495759023788052)),
#   (np.int64(1), np.float64(0.5990381639003575))],
#  [(np.int64(0), np.float64(-2.1561282118767227)),
#   (np.int64(1), np.float64(-0.43460302542871754))],
#  [(np.int64(0), np.float64(-1.4715652384514246)),
#   (np.int64(1), np.float64(-0.6146140595436556))],
#  [(np.int64(0), np.float64(-0.8501937372265461)),
#   (np.int64(1), np.float64(-0.16767262702314598))],
#  [(np.int64(0), np.float64(-2.507552146474812)),
#   (np.int64(1), np.float64(-0.03289945777775317))],
#  [(np.int64(0), np.float64(-0.7533793953159637)),
#   (np.int64(1), np.float64(-0.07936723669556385))],
#  [(np.int64(0), np.float64(-1.8650036991697472)),
#   (np.int64(1), np.float64(-0.9575055203189329))],
#  [(np.int64(0), np.float64(-0.5645328360097492)),
#   (np.int64(1), np.float64(-0.03131199408190781))],
#  [(np.int64(0), np.float64(-0.15297743466697605)),
#   (np.int64(1), np.float64(-0.08899475257389855))],
#  [(np.int64(0), np.float64(-3.6032478695345374)),
#   (np.int64(1), np.float64(-0.8333094254009846))],
#  [(np.int64(0), np.float64(-20.13939537254604)),
#   (np.int64(1), np.float64(-13.617177561927145))],
#  [(np.int64(0), np.float64(-2.0735611812547106)),
#   (np.int64(1), np.float64(1.298519484391992))],
#  [(np.int64(0), np.float64(-0.802763822919566)),
#   (np.int64(1), np.float64(-0.6198841117123036))],
#  [(np.int64(0), np.float64(-1.1859584891405033)),
#   (np.int64(1), np.float64(0.9768188477317302))],
#  [(np.int64(0), np.float64(-0.9580722799917428)),
#   (np.int64(1), np.float64(-0.1776444579126971))],
#  [(np.int64(0), np.float64(-73.99207483017867)),
#   (np.int64(1), np.float64(30.46085508243548))],
#  [(np.int64(0), np.float64(-1.132290263781646)),
#   (np.int64(1), np.float64(1.0614921157170825))],
#  [(np.int64(0), np.float64(-6.906652222623076)),
#   (np.int64(1), np.float64(-3.170597636677913))],
#  [(np.int64(0), np.float64(-1.7070970103225849)),
#   (np.int64(1), np.float64(-0.3035249311408215))],
#  [(np.int64(0), np.float64(-0.8016413716442298)),
#   (np.int64(1), np.float64(-0.21807950707592355))],
#  [(np.int64(0), np.float64(-3.661898929872716)),
#   (np.int64(1), np.float64(1.1929704493505495))],
#  [(np.int64(0), np.float64(-0.8438361124423001)),
#   (np.int64(1), np.float64(-0.308459853984404))],
#  [(np.int64(0), np.float64(-0.5017553725127708)),
#   (np.int64(1), np.float64(-0.15032837471228508))],
#  [(np.int64(0), np.float64(-0.7837943690382492)),
#   (np.int64(1), np.float64(0.029417432708837517))],
#  [(np.int64(0), np.float64(-0.7092936220060968)),
#   (np.int64(1), np.float64(-0.042196005737110055))],
#  [(np.int64(0), np.float64(-0.2092470109808297)),
#   (np.int64(1), np.float64(-0.03217613083248758))],
#  [(np.int64(0), np.float64(-0.18150141279726084)),
#   (np.int64(1), np.float64(-0.021358823109168423))],
#  [(np.int64(0), np.float64(-3.43534670037914)),
#   (np.int64(1), np.float64(1.1492659414765443))],
#  [(np.int64(0), np.float64(-0.27611990134960634)),
#   (np.int64(1), np.float64(0.08603187230871431))],
#  [(np.int64(0), np.float64(-2.5502876877193255)),
#   (np.int64(1), np.float64(-0.22922003963165552))],
#  [(np.int64(0), np.float64(-1.1196337728330172)),
#   (np.int64(1), np.float64(0.764888548005233))],
#  [(np.int64(0), np.float64(-1.5595030664558358)),
#   (np.int64(1), np.float64(-0.4303126008214643))],
#  [(np.int64(0), np.float64(-7.6949819314591075)),
#   (np.int64(1), np.float64(-4.064624197073545))],
#  [(np.int64(0), np.float64(-0.9239688850939197)),
#   (np.int64(1), np.float64(1.2522279280328024))],
#  [(np.int64(0), np.float64(-1.1911392537641272)),
#   (np.int64(1), np.float64(0.9819500191058899))],
#  [(np.int64(0), np.float64(-0.008787221928502006)),
#   (np.int64(1), np.float64(-0.0009703871427405712))],
#  [(np.int64(0), np.float64(-1.9827574940259651)),
#   (np.int64(1), np.float64(-0.40068435231251354))],
#  [(np.int64(0), np.float64(-11.356473089926814)),
#   (np.int64(1), np.float64(-7.237038353649139))],
#  [(np.int64(0), np.float64(-0.8740064030679157)),
#   (np.int64(1), np.float64(0.6083769554668238))],
#  [(np.int64(0), np.float64(-1.3125540232968411)),
#   (np.int64(1), np.float64(-0.12047280782547716))],
#  [(np.int64(0), np.float64(-2.3484525787394896)),
#   (np.int64(1), np.float64(-1.186739429854861))],
#  [(np.int64(0), np.float64(-0.7420679192794751)),
#   (np.int64(1), np.float64(0.610023668619442))],
#  [(np.int64(0), np.float64(-3.752353776761184)),
#   (np.int64(1), np.float64(1.3710541660746354))],
#  [(np.int64(0), np.float64(-0.35560801155251154)),
#   (np.int64(1), np.float64(0.40603400845771176))],
#  [(np.int64(0), np.float64(-1.0770742211135704)),
#   (np.int64(1), np.float64(0.276269535025999))],
#  [(np.int64(0), np.float64(-0.786932334587886)),
#   (np.int64(1), np.float64(-0.42522142350055875))],
#  [(np.int64(0), np.float64(-0.6100801335277926)),
#   (np.int64(1), np.float64(0.018830048596886168))],
#  [(np.int64(0), np.float64(-0.8493724352515789)),
#   (np.int64(1), np.float64(0.7716231914373239))],
#  [(np.int64(0), np.float64(-1.2237412273026376)),
#   (np.int64(1), np.float64(0.06112869619948233))],
#  [(np.int64(0), np.float64(-21.796341395949128)),
#   (np.int64(1), np.float64(7.063427942185528))],
#  [(np.int64(0), np.float64(-0.7877063700538633)),
#   (np.int64(1), np.float64(-0.13604059468212437))],
#  [(np.int64(0), np.float64(-0.45603573473901005)),
#   (np.int64(1), np.float64(0.2525495976832274))],
#  [(np.int64(0), np.float64(-0.6444088359573735)),
#   (np.int64(1), np.float64(0.19239061385672548))],
#  [(np.int64(0), np.float64(-0.2500384770065866)),
#   (np.int64(1), np.float64(-0.359168019896214))],
#  [(np.int64(0), np.float64(-7.550920580756831)),
#   (np.int64(1), np.float64(-2.8538948703514406))],
#  [(np.int64(0), np.float64(-2.472575993072343)),
#   (np.int64(1), np.float64(0.9308985033523886))],
#  [(np.int64(0), np.float64(-1.5221818766564403)),
#   (np.int64(1), np.float64(0.09343425208090869))],
#  [(np.int64(0), np.float64(-3.114027671371491)),
#   (np.int64(1), np.float64(0.06039906918015518))],
#  [(np.int64(0), np.float64(-0.7399590582979071)),
#   (np.int64(1), np.float64(1.0786147293296202))],
#  [(np.int64(0), np.float64(-1.1529376372306321)),
#   (np.int64(1), np.float64(0.016710704544657264))],
#  [(np.int64(0), np.float64(-1.765705062740161)),
#   (np.int64(1), np.float64(0.3146935189758284))],
#  [(np.int64(0), np.float64(-0.46784643849767266)),
#   (np.int64(1), np.float64(0.46339454211367687))],
#  [(np.int64(0), np.float64(-1.974457513323374)),
#   (np.int64(1), np.float64(0.9696560825577438))],
#  [(np.int64(0), np.float64(-0.12024806304370744)),
#   (np.int64(1), np.float64(0.004511898385396556))],
#  [(np.int64(0), np.float64(-2.4441124305521034)),
#   (np.int64(1), np.float64(0.7254272414367682))],
#  [(np.int64(0), np.float64(-0.5977333882668269)),
#   (np.int64(1), np.float64(1.0770453619060707))],
#  [(np.int64(0), np.float64(-2.3623018547169377)),
#   (np.int64(1), np.float64(0.1947853559427665))],
#  [(np.int64(0), np.float64(-0.18964886322434835)),
#   (np.int64(1), np.float64(-0.01254367906869822))],
#  [(np.int64(0), np.float64(-0.4582027633588253)),
#   (np.int64(1), np.float64(-0.19587568674727235))],
#  [(np.int64(0), np.float64(-6.565248040602095)),
#   (np.int64(1), np.float64(-2.2442230307439868))],
#  [(np.int64(0), np.float64(-0.7900060850167333)),
#   (np.int64(1), np.float64(-0.3919346102073171))],
#  [(np.int64(0), np.float64(-0.4692062823021288)),
#   (np.int64(1), np.float64(0.5914815696179806))],
#  [(np.int64(0), np.float64(-1.0625176125390117)),
#   (np.int64(1), np.float64(0.44351026539165733))],
#  [(np.int64(0), np.float64(-0.6626952229456173)),
#   (np.int64(1), np.float64(-0.22563592520339448))],
#  [(np.int64(0), np.float64(-11.22908077249465)),
#   (np.int64(1), np.float64(-9.984226802637016))],
#  [(np.int64(0), np.float64(-0.2087315786665649)),
#   (np.int64(1), np.float64(0.1690929721156685))],
#  [(np.int64(0), np.float64(-0.4895767154148727)),
#   (np.int64(1), np.float64(0.6561262541073707))],
#  [(np.int64(0), np.float64(-8.957455481762478)),
#   (np.int64(1), np.float64(5.284832853874051))],
#  [(np.int64(0), np.float64(-1.087599489587336)),
#   (np.int64(1), np.float64(-0.22514569453966876))],
#  [(np.int64(0), np.float64(-0.31635021519951034)),
#   (np.int64(1), np.float64(0.489794710027958))],
#  [(np.int64(0), np.float64(-0.45339218060750747)),
#   (np.int64(1), np.float64(0.3072486828305742))],
#  [(np.int64(0), np.float64(-2.1390904794569594)),
#   (np.int64(1), np.float64(-0.5419737710642527))],
#  [(np.int64(0), np.float64(-2.6979765787122822)),
#   (np.int64(1), np.float64(-0.8182967430044695))],
#  [(np.int64(0), np.float64(-1.460950867888384)),
#   (np.int64(1), np.float64(0.518279842837315))],
#  [(np.int64(0), np.float64(-5.02881094639641)),
#   (np.int64(1), np.float64(-0.4485505045039228))],
#  [(np.int64(0), np.float64(-1.2801766245507378)),
#   (np.int64(1), np.float64(0.28687029018864296))],
#  [(np.int64(0), np.float64(-0.9516353875580138)),
#   (np.int64(1), np.float64(0.7555572171568314))],
#  [(np.int64(0), np.float64(-0.6407496560452768)),
#   (np.int64(1), np.float64(-0.054039324664146876))],
#  [(np.int64(0), np.float64(-1.546829508197425)),
#   (np.int64(1), np.float64(0.47462532039012384))],
#  [(np.int64(0), np.float64(-2.283191134655017)),
#   (np.int64(1), np.float64(-1.3166861081390804))],
#  [(np.int64(0), np.float64(-2.1069091703586693)),
#   (np.int64(1), np.float64(-0.3221606693888805))],
#  [(np.int64(0), np.float64(-1.3295266885109986)),
#   (np.int64(1), np.float64(-0.10182268587424889))],
#  [(np.int64(0), np.float64(-1.744743627762278)),
#   (np.int64(1), np.float64(0.2275311712993302))],
#  [(np.int64(0), np.float64(-1.6178101981579496)),
#   (np.int64(1), np.float64(1.770779874320252))],
#  [(np.int64(0), np.float64(-0.5750765909276458)),
#   (np.int64(1), np.float64(-0.1148497312334292))],
#  [(np.int64(0), np.float64(-1.618182973571444)),
#   (np.int64(1), np.float64(-0.7646441956673756))],
#  [(np.int64(0), np.float64(-0.1854131275492708)),
#   (np.int64(1), np.float64(-0.024809676155332284))],
#  [(np.int64(0), np.float64(-1.1537351507188107)),
#   (np.int64(1), np.float64(1.2936129117245079))],
#  [(np.int64(0), np.float64(-6.572584260844396)),
#   (np.int64(1), np.float64(-4.150220697713003))],
#  [(np.int64(0), np.float64(-14.153806871330637)),
#   (np.int64(1), np.float64(9.11489275263106))],
#  [(np.int64(0), np.float64(-1.3373768951621916)),
#   (np.int64(1), np.float64(-0.5172461317905866))],
#  [(np.int64(0), np.float64(-1.5535689709361702)),
#   (np.int64(1), np.float64(-0.684939276854174))],
#  [(np.int64(0), np.float64(-1.0889407001834557)),
#   (np.int64(1), np.float64(0.16479523456409825))],
#  [(np.int64(0), np.float64(-1.3616589629614941)),
#   (np.int64(1), np.float64(0.5904592925609313))],
#  [(np.int64(0), np.float64(-1.1813087710355976)),
#   (np.int64(1), np.float64(0.392566620907215))],
#  [],
#  [(np.int64(0), np.float64(-0.438163031291896)),
#   (np.int64(1), np.float64(-0.08561689317834074))],
#  [(np.int64(0), np.float64(-1.407395061475718)),
#   (np.int64(1), np.float64(0.39594223605072343))],
#  [(np.int64(0), np.float64(-0.4525411353812462)),
#   (np.int64(1), np.float64(-0.08111711052380774))],
#  [(np.int64(0), np.float64(-2.3153618004643928)),
#   (np.int64(1), np.float64(-0.2642481028469857))],
#  [(np.int64(0), np.float64(-0.9162431046398994)),
#   (np.int64(1), np.float64(-0.17451777414470643))],
#  [(np.int64(0), np.float64(-0.12466537473760347)),
#   (np.int64(1), np.float64(-0.002594693010313543))],
#  [(np.int64(0), np.float64(-21.29388565100167)),
#   (np.int64(1), np.float64(17.818440957730452))],
#  [(np.int64(0), np.float64(-0.42551347206841494)),
#   (np.int64(1), np.float64(0.2791998527648899))],
#  [(np.int64(0), np.float64(-0.2252965635441837)),
#   (np.int64(1), np.float64(0.16511048936524236))],
#  [(np.int64(0), np.float64(-0.8178437748977081)),
#   (np.int64(1), np.float64(-0.3800935775266997))],
#  [(np.int64(0), np.float64(-2.517611294970875)),
#   (np.int64(1), np.float64(-1.280307235996859))],
#  [(np.int64(0), np.float64(-0.6362476982220918)),
#   (np.int64(1), np.float64(-0.2915600722281313))],
#  [(np.int64(0), np.float64(-0.13475038227033753)),
#   (np.int64(1), np.float64(0.029276026735064686))],
#  [(np.int64(0), np.float64(-0.7346407253809869)),
#   (np.int64(1), np.float64(0.5797310728861644))],
#  [(np.int64(0), np.float64(-0.08776506335657137)),
#   (np.int64(1), np.float64(-0.02440724510298843))],
#  [(np.int64(0), np.float64(-0.29479331115156227)),
#   (np.int64(1), np.float64(0.026776599868162512))],
#  [(np.int64(0), np.float64(-1.3696121142128233)),
#   (np.int64(1), np.float64(0.3388631594805247))],
#  [(np.int64(0), np.float64(-0.5431624780757099)),
#   (np.int64(1), np.float64(0.7008496058425612))],
#  [(np.int64(0), np.float64(-0.07131154787288758)),
#   (np.int64(1), np.float64(0.17522540685001053))],
#  [(np.int64(0), np.float64(-0.9698460139474537)),
#   (np.int64(1), np.float64(-0.4333748247999889))],
#  [(np.int64(0), np.float64(-1.0812403587409152)),
#   (np.int64(1), np.float64(1.2850418410747502))],
#  [(np.int64(0), np.float64(-0.9945829711105891)),
#   (np.int64(1), np.float64(0.06836205653309432))],
#  [(np.int64(0), np.float64(-8.779579175995668)),
#   (np.int64(1), np.float64(-3.454941614260776))],
#  [(np.int64(0), np.float64(-1.028056026015793)),
#   (np.int64(1), np.float64(-0.25254633888913575))],
#  [(np.int64(0), np.float64(-8.673081609774522)),
#   (np.int64(1), np.float64(-3.8819072957585905))],
#  [(np.int64(0), np.float64(-1.8392548216278102)),
#   (np.int64(1), np.float64(2.1623497086195007))],
#  [(np.int64(0), np.float64(-1.6513428312123122)),
#   (np.int64(1), np.float64(0.0763282086430927))],
#  [(np.int64(0), np.float64(-1.3829684586947597)),
#   (np.int64(1), np.float64(-0.04765042338014327))],
#  [(np.int64(0), np.float64(-2.4379156188450657)),
#   (np.int64(1), np.float64(-1.3441305554287628))],
#  [(np.int64(0), np.float64(-0.7637947887936045)),
#   (np.int64(1), np.float64(0.02913708205530613))],
#  [(np.int64(0), np.float64(-0.8714597557830572)),
#   (np.int64(1), np.float64(-0.5918709283382894))],
#  [(np.int64(0), np.float64(-1.1949099133323404)),
#   (np.int64(1), np.float64(0.5115200073645608))],
#  [(np.int64(0), np.float64(-1.0411929926977876)),
#   (np.int64(1), np.float64(0.19460507876289557))],
#  [(np.int64(0), np.float64(-1.637059851564289)),
#   (np.int64(1), np.float64(0.5658909867146))],
#  [(np.int64(0), np.float64(-0.8671545294814652)),
#   (np.int64(1), np.float64(-0.20779653132109432))],
#  [(np.int64(0), np.float64(-0.6130079289408196)),
#   (np.int64(1), np.float64(0.8720035948654734))],
#  [(np.int64(0), np.float64(-1.2902052997167746)),
#   (np.int64(1), np.float64(-0.5152446166829256))],
#  [(np.int64(0), np.float64(-1.1940372726596622)),
#   (np.int64(1), np.float64(0.92877926757569))],
#  [(np.int64(0), np.float64(-0.1825511981065435)),
#   (np.int64(1), np.float64(-0.04865266628772414))],
#  [(np.int64(0), np.float64(-1.0972945464923243)),
#   (np.int64(1), np.float64(-0.06421236162100545))],
#  [(np.int64(0), np.float64(-0.2312110318576501)),
#   (np.int64(1), np.float64(0.07604339114227207))],
#  [(np.int64(0), np.float64(-0.4785409197409325)),
#   (np.int64(1), np.float64(-0.19070319513188908))],
#  [(np.int64(0), np.float64(-2.3534389531304187)),
#   (np.int64(1), np.float64(-1.4422574557459775))],
#  [(np.int64(0), np.float64(-2.088708080678337)),
#   (np.int64(1), np.float64(-0.7655826309079032))],
#  [(np.int64(0), np.float64(-1.244316934677429)),
#   (np.int64(1), np.float64(0.016054589755930507))],
#  [(np.int64(0), np.float64(-7.297439880707762)),
#   (np.int64(1), np.float64(2.055743920752048))],
#  [(np.int64(0), np.float64(-0.8504193946251994)),
#   (np.int64(1), np.float64(0.32983601147215236))],
#  [(np.int64(0), np.float64(-0.7528623208917745)),
#   (np.int64(1), np.float64(0.20185107659076107))],
#  [(np.int64(0), np.float64(-1.519246271696972)),
#   (np.int64(1), np.float64(0.8131406633997406))],
#  [(np.int64(0), np.float64(-0.4131741597303593)),
#   (np.int64(1), np.float64(0.08659279003170856))],
#  [(np.int64(0), np.float64(-0.6871362802479554)),
#   (np.int64(1), np.float64(-0.3313985799853471))],
#  [(np.int64(0), np.float64(-1.6887071872185953)),
#   (np.int64(1), np.float64(1.3071430717083983))],
#  [(np.int64(0), np.float64(-0.10389307812777135)),
#   (np.int64(1), np.float64(0.09079958516900748))],
#  [(np.int64(0), np.float64(-0.09826754232538107)),
#   (np.int64(1), np.float64(0.12283552634344659))],
#  [(np.int64(0), np.float64(-0.39973907114498763)),
#   (np.int64(1), np.float64(0.39499933550756083))],
#  [(np.int64(0), np.float64(-8.233030711000346)),
#   (np.int64(1), np.float64(-3.5982965443118657))],
#  [(np.int64(0), np.float64(-2.130139221867816)),
#   (np.int64(1), np.float64(2.0700231912398683))],
#  [(np.int64(0), np.float64(-2.0954677125207826)),
#   (np.int64(1), np.float64(-0.7568252469510918))],
#  [(np.int64(0), np.float64(-0.9230331482024987)),
#   (np.int64(1), np.float64(-0.4878510718250199))],
#  [(np.int64(0), np.float64(-1.4250734748587113)),
#   (np.int64(1), np.float64(-1.1615770126814249))],
#  [(np.int64(0), np.float64(-4.305296731458717)),
#   (np.int64(1), np.float64(-1.2934631625429973))],
#  [(np.int64(0), np.float64(-0.35260213295744475)),
#   (np.int64(1), np.float64(0.7642390235255702))],
#  [(np.int64(0), np.float64(-0.4857729988675049)),
#   (np.int64(1), np.float64(-0.3292037759318512))],
#  [(np.int64(0), np.float64(-1.8673198094885863)),
#   (np.int64(1), np.float64(-0.08774552246360785))],
#  [(np.int64(0), np.float64(-0.7129512720904365)),
#   (np.int64(1), np.float64(0.18490114630055382))],
#  [(np.int64(0), np.float64(-0.8261579195790815)),
#   (np.int64(1), np.float64(-0.20325934245586205))],
#  [(np.int64(0), np.float64(-0.6611431317023267)),
#   (np.int64(1), np.float64(0.45042567033545977))],
#  [(np.int64(0), np.float64(-0.8418406510094726)),
#   (np.int64(1), np.float64(-0.6960574735168186))],
#  [(np.int64(0), np.float64(-0.4267014296018687)),
#   (np.int64(1), np.float64(-0.06317406459450307))],
#  [(np.int64(0), np.float64(-3.4727779668177208)),
#   (np.int64(1), np.float64(-1.400145560792691))],
#  [(np.int64(0), np.float64(-10.660373908528765)),
#   (np.int64(1), np.float64(-3.3052643124582963))],
#  [(np.int64(0), np.float64(-1.8200282245853334)),
#   (np.int64(1), np.float64(1.591711848086623))],
#  [(np.int64(0), np.float64(-0.7245106109476782)),
#   (np.int64(1), np.float64(0.5747181521358935))],
#  [(np.int64(0), np.float64(-0.6524096805656296)),
#   (np.int64(1), np.float64(0.37027670669723245))],
#  [(np.int64(0), np.float64(-5.35384631203644)),
#   (np.int64(1), np.float64(0.2787769063708955))],
#  [(np.int64(0), np.float64(-9.05900904221265)),
#   (np.int64(1), np.float64(-2.677590378409993))],
#  [(np.int64(0), np.float64(-3.305607598307325)),
#   (np.int64(1), np.float64(2.818821934220164))],
#  [(np.int64(0), np.float64(-0.5436094212835275)),
#   (np.int64(1), np.float64(-0.08456343493891484))],
#  [(np.int64(0), np.float64(-0.4078442449275867)),
#   (np.int64(1), np.float64(0.5506833693287191))],
#  [(np.int64(0), np.float64(-2.0857186680776016)),
#   (np.int64(1), np.float64(-0.40983933335288647))],
#  [(np.int64(0), np.float64(-0.3306293268740806)),
#   (np.int64(1), np.float64(-0.12854817831674026))],
#  [(np.int64(0), np.float64(-0.44862459565441004)),
#   (np.int64(1), np.float64(-0.1201037986492334))],
#  [(np.int64(0), np.float64(-0.456021903421818)),
#   (np.int64(1), np.float64(-0.0029643740413244496))],
#  [],
#  [(np.int64(0), np.float64(-0.47168400559676843)),
#   (np.int64(1), np.float64(-0.05966609566640178))],
#  [(np.int64(0), np.float64(-0.9545675499263561)),
#   (np.int64(1), np.float64(-0.06715713403634735))],
#  [(np.int64(0), np.float64(-4.415084146422256)),
#   (np.int64(1), np.float64(1.9512003022506386))],
#  [(np.int64(0), np.float64(-0.7456998166418082)),
#   (np.int64(1), np.float64(0.4625379391414162))],
#  [(np.int64(0), np.float64(-0.7901525430733167)),
#   (np.int64(1), np.float64(-0.14969745930636028))],
#  [(np.int64(0), np.float64(-0.877683242143972)),
#   (np.int64(1), np.float64(-0.7599678614161722))],
#  [(np.int64(0), np.float64(-0.01676638395854257)),
#   (np.int64(1), np.float64(0.0441982789335624))],
#  [(np.int64(0), np.float64(-18.18561158744959)),
#   (np.int64(1), np.float64(-7.671633038516101))],
#  [(np.int64(0), np.float64(-1.6337454182055666)),
#   (np.int64(1), np.float64(0.506396011930918))],
#  [(np.int64(0), np.float64(-5.120148021729926)),
#   (np.int64(1), np.float64(1.8623851023448237))],
#  [(np.int64(0), np.float64(-1.1151310815482256)),
#   (np.int64(1), np.float64(0.5554431884269508))],
#  [(np.int64(0), np.float64(-2.2052577946755854)),
#   (np.int64(1), np.float64(0.13720864176594066))],
#  [(np.int64(0), np.float64(-0.6750581616207814)),
#   (np.int64(1), np.float64(0.41778995804784286))],
#  [(np.int64(0), np.float64(-1.9832871161458754)),
#   (np.int64(1), np.float64(0.7841011797137435))],
#  [(np.int64(0), np.float64(-7.651497316059471)),
#   (np.int64(1), np.float64(-4.598710454337817))],
#  [(np.int64(0), np.float64(-3.926844562749197)),
#   (np.int64(1), np.float64(1.6840190114744407))],
#  [(np.int64(0), np.float64(-7.071578328533353)),
#   (np.int64(1), np.float64(-2.6379327436033986))],
#  [(np.int64(0), np.float64(-6.858515690511397)),
#   (np.int64(1), np.float64(-3.742452879397271))],
#  [(np.int64(0), np.float64(-2.439575792031966)),
#   (np.int64(1), np.float64(0.7037011169595514))],
#  [(np.int64(0), np.float64(-9.66378249952341)),
#   (np.int64(1), np.float64(0.6671934610385561))],
#  [(np.int64(0), np.float64(-2.8278405918398883)),
#   (np.int64(1), np.float64(0.11714547890898955))],
#  [(np.int64(0), np.float64(-2.201622638785928)),
#   (np.int64(1), np.float64(0.7203099534758111))],
#  [(np.int64(0), np.float64(-17.877730759489186)),
#   (np.int64(1), np.float64(-6.044807198130508))],
#  [(np.int64(0), np.float64(-6.326993148699586)),
#   (np.int64(1), np.float64(2.2639832620101115))],
#  [(np.int64(0), np.float64(-0.45292853979813974)),
#   (np.int64(1), np.float64(0.3781859700477005))],
#  [(np.int64(0), np.float64(-0.5984067578159249)),
#   (np.int64(1), np.float64(0.20417237691251638))],
#  [(np.int64(0), np.float64(-0.7131187672910455)),
#   (np.int64(1), np.float64(-0.18658558124612182))],
#  [(np.int64(0), np.float64(-3.6250924996756004)),
#   (np.int64(1), np.float64(1.3864299831084286))],
#  [(np.int64(0), np.float64(-0.5450732723720217)),
#   (np.int64(1), np.float64(-0.13256803636894374))],
#  [(np.int64(0), np.float64(-0.5338777722268272)),
#   (np.int64(1), np.float64(-0.5568375466561434))],
#  [(np.int64(0), np.float64(-0.9451393480822451)),
#   (np.int64(1), np.float64(-0.10827958408091991))],
#  [(np.int64(0), np.float64(-0.396842276359944)),
#   (np.int64(1), np.float64(-0.11342616512680466))],
#  [(np.int64(0), np.float64(-0.7878454378213501)),
#   (np.int64(1), np.float64(0.1680837301017601))],
#  [(np.int64(0), np.float64(-0.4089190727607409)),
#   (np.int64(1), np.float64(0.304940918357167))],
#  [(np.int64(0), np.float64(-3.4917036602987803)),
#   (np.int64(1), np.float64(0.8216701078041541))],
#  [(np.int64(0), np.float64(-0.1407801932338323)),
#   (np.int64(1), np.float64(-0.08462691376659585))],
#  [],
#  [(np.int64(0), np.float64(-3.5098436764451564)),
#   (np.int64(1), np.float64(0.297747232579567))],
#  [(np.int64(0), np.float64(-1.7812086805039333)),
#   (np.int64(1), np.float64(-1.2158550686062335))],
#  [(np.int64(0), np.float64(-0.7708445665679523)),
#   (np.int64(1), np.float64(-0.27191662246729176))],
#  [(np.int64(0), np.float64(-3.6624045386113924)),
#   (np.int64(1), np.float64(-1.2548516640221323))],
#  [(np.int64(0), np.float64(-11.681945988009831)),
#   (np.int64(1), np.float64(-4.81513265921407))],
#  [(np.int64(0), np.float64(-0.34369336960731867)),
#   (np.int64(1), np.float64(-0.053879906488363584))],
#  [(np.int64(0), np.float64(-1.6671116328143099)),
#   (np.int64(1), np.float64(1.047210500733085))],
#  [(np.int64(0), np.float64(-5.039482551921365)),
#   (np.int64(1), np.float64(1.170016820984629))],
#  [(np.int64(0), np.float64(-0.3899521757381911)),
#   (np.int64(1), np.float64(0.1482339859163322))],
#  [(np.int64(0), np.float64(-1.2798847828227775)),
#   (np.int64(1), np.float64(0.6086077302262448))],
#  [(np.int64(0), np.float64(-0.43801360183277416)),
#   (np.int64(1), np.float64(-0.038819050932181305))],
#  [(np.int64(0), np.float64(-0.9635911075523307)),
#   (np.int64(1), np.float64(-0.26887370610518874))],
#  [(np.int64(0), np.float64(-0.40046356735940236)),
#   (np.int64(1), np.float64(0.4192248000676381))],
#  [(np.int64(0), np.float64(-0.5357494858613934)),
#   (np.int64(1), np.float64(0.27355683488272525))],
#  [(np.int64(0), np.float64(-1.4189119813188351)),
#   (np.int64(1), np.float64(-0.49162114157441983))],
#  [(np.int64(0), np.float64(-0.41516156520919456)),
#   (np.int64(1), np.float64(0.08937713236699818))],
#  [(np.int64(0), np.float64(-1.1719543623844162)),
#   (np.int64(1), np.float64(0.7006778904692268))],
#  [(np.int64(0), np.float64(-0.1798284879719177)),
#   (np.int64(1), np.float64(-0.1144395309890216))],
#  [(np.int64(0), np.float64(-0.11546523653272167)),
#   (np.int64(1), np.float64(-0.05987893001932065))],
#  [(np.int64(0), np.float64(-6.113062831112626)),
#   (np.int64(1), np.float64(-1.8058670162274753))],
#  [(np.int64(0), np.float64(-0.8734852597737469)),
#   (np.int64(1), np.float64(0.8652961044125211))],
#  [(np.int64(0), np.float64(-1.1024459481831288)),
#   (np.int64(1), np.float64(0.5454313303545749))],
#  [(np.int64(0), np.float64(-12.792870950088595)),
#   (np.int64(1), np.float64(8.838527162306445))],
#  [(np.int64(0), np.float64(-0.6565250575438707)),
#   (np.int64(1), np.float64(0.6805098415833555))],
#  [(np.int64(0), np.float64(-0.7255856291516337)),
#   (np.int64(1), np.float64(0.33377266601572947))],
#  [(np.int64(0), np.float64(-0.19184912603866355)),
#   (np.int64(1), np.float64(0.0435988087531581))],
#  [(np.int64(0), np.float64(-1.5227304433455409)),
#   (np.int64(1), np.float64(-0.33259099529861086))],
#  [(np.int64(0), np.float64(-1.3044454803504462)),
#   (np.int64(1), np.float64(0.04780114237717864))],
#  [(np.int64(0), np.float64(-2.5155637033421825)),
#   (np.int64(1), np.float64(-0.6829446311987226))],
#  [(np.int64(0), np.float64(-0.8345690159724198)),
#   (np.int64(1), np.float64(0.5016651849248158))],
#  [(np.int64(0), np.float64(-0.2978548841534645)),
#   (np.int64(1), np.float64(0.005151716914028449))],
#  [(np.int64(0), np.float64(-0.15783367415031932)),
#   (np.int64(1), np.float64(0.2347214458974105))],
#  [(np.int64(0), np.float64(-0.0005472632488743535)),
#   (np.int64(1), np.float64(-0.0002986048871623976))],
#  [(np.int64(0), np.float64(-5.279104709972656)),
#   (np.int64(1), np.float64(-2.553808655304561))],
#  [(np.int64(0), np.float64(-0.5552141800168554)),
#   (np.int64(1), np.float64(0.7226777186486532))],
#  [(np.int64(0), np.float64(-0.08233148639266043)),
#   (np.int64(1), np.float64(-0.04299323841176546))],
#  [(np.int64(0), np.float64(-0.4204575114564849)),
#   (np.int64(1), np.float64(0.1656077855270385))],
#  [(np.int64(0), np.float64(-0.9492633800212428)),
#   (np.int64(1), np.float64(-0.11367052034075817))],
#  [(np.int64(0), np.float64(-0.05962390957080682)),
#   (np.int64(1), np.float64(-0.04032368204883217))],
#  [(np.int64(0), np.float64(-0.45580250313773385)),
#   (np.int64(1), np.float64(-0.3724535453934811))],
#  [(np.int64(0), np.float64(-2.026504295662139)),
#   (np.int64(1), np.float64(-0.45705570804397627))],
#  [(np.int64(0), np.float64(-0.4364260341103186)),
#   (np.int64(1), np.float64(-0.06911179537994655))],
#  [(np.int64(0), np.float64(-3.174249575728628)),
#   (np.int64(1), np.float64(2.726625662543015))],
#  [(np.int64(0), np.float64(-0.27303450987141586)),
#   (np.int64(1), np.float64(0.1675869147331492))],
#  [(np.int64(0), np.float64(-10.507694196579433)),
#   (np.int64(1), np.float64(1.309336264950163))],
#  [(np.int64(0), np.float64(-2.6000418026083216)),
#   (np.int64(1), np.float64(0.3201493954648291))],
#  [],
#  [(np.int64(0), np.float64(-0.6778603965934903)),
#   (np.int64(1), np.float64(-0.16167046125134418))],
#  [(np.int64(0), np.float64(-2.869895143273918)),
#   (np.int64(1), np.float64(0.5910883091870959))],
#  [(np.int64(0), np.float64(-1.8316945989661917)),
#   (np.int64(1), np.float64(-0.6417992018757929))],
#  [(np.int64(0), np.float64(-1.3704973091306794)),
#   (np.int64(1), np.float64(0.646484386755323))],
#  [(np.int64(0), np.float64(-1.2991631761047804)),
#   (np.int64(1), np.float64(0.0001886746967753343))],
#  [(np.int64(0), np.float64(-1.1075865378402892)),
#   (np.int64(1), np.float64(0.9140564346112009))],
#  [(np.int64(0), np.float64(-0.8180824687374578)),
#   (np.int64(1), np.float64(1.1560470316532743))],
#  [(np.int64(0), np.float64(-2.5718416742809733)),
#   (np.int64(1), np.float64(0.5089577864004334))],
#  [(np.int64(0), np.float64(-2.8100759061242333)),
#   (np.int64(1), np.float64(-0.2452855707776415))],
#  [(np.int64(0), np.float64(-2.6114794269866666)),
#   (np.int64(1), np.float64(-1.184175012987645))],
#  [(np.int64(0), np.float64(-0.5407942713472385)),
#   (np.int64(1), np.float64(0.3913591713841788))],
#  [(np.int64(0), np.float64(-1.5539083947559396)),
#   (np.int64(1), np.float64(-0.17083715778068212))],
#  [(np.int64(0), np.float64(-1.3848705013143259)),
#   (np.int64(1), np.float64(-0.7644709861431443))],
#  [(np.int64(0), np.float64(-8.798129275523586)),
#   (np.int64(1), np.float64(-5.95550256991184))],
#  [(np.int64(0), np.float64(-1.2405917807586933)),
#   (np.int64(1), np.float64(0.1958557458500877))],
#  [(np.int64(0), np.float64(-2.8894162929583054)),
#   (np.int64(1), np.float64(2.0192710405411534))],
#  [(np.int64(0), np.float64(-2.2758648939857844)),
#   (np.int64(1), np.float64(2.1235641519524204))],
#  [(np.int64(0), np.float64(-0.2625616765331305)),
#   (np.int64(1), np.float64(-0.018989259127551613))],
#  [(np.int64(0), np.float64(-0.5877681259694276)),
#   (np.int64(1), np.float64(-0.035476009825720814))],
#  [(np.int64(0), np.float64(-1.383565525860684)),
#   (np.int64(1), np.float64(0.5111856140619562))],
#  [(np.int64(0), np.float64(-0.39582671084835525)),
#   (np.int64(1), np.float64(-0.009253710143742891))],
#  [(np.int64(0), np.float64(-0.520253882359401)),
#   (np.int64(1), np.float64(-0.007175423403725745))],
#  [(np.int64(0), np.float64(-1.391635320352089)),
#   (np.int64(1), np.float64(-0.07396116339500447))],
#  [(np.int64(0), np.float64(-1.2320653462136517)),
#   (np.int64(1), np.float64(0.11575013524698223))],
#  [(np.int64(0), np.float64(-0.8961152172241434)),
#   (np.int64(1), np.float64(0.9323211250248528))],
#  [(np.int64(0), np.float64(-1.5644453538302736)),
#   (np.int64(1), np.float64(-0.45408855167669515))],
#  [(np.int64(0), np.float64(-0.2853825042407983)),
#   (np.int64(1), np.float64(-0.00782816772277438))],
#  [(np.int64(0), np.float64(-0.7621942368352514)),
#   (np.int64(1), np.float64(-0.08114910983664253))],
#  [(np.int64(0), np.float64(-0.8498950806816341)),
#   (np.int64(1), np.float64(-0.5877770600822658))],
#  [(np.int64(0), np.float64(-2.4468520641519698)),
#   (np.int64(1), np.float64(-0.6337371108191687))],
#  [(np.int64(0), np.float64(-1.6038498639649463)),
#   (np.int64(1), np.float64(0.1055209775513552))],
#  [(np.int64(0), np.float64(-1.9347801398654612)),
#   (np.int64(1), np.float64(-0.41314440824403864))],
#  [(np.int64(0), np.float64(-0.5305345601861432)),
#   (np.int64(1), np.float64(0.1442523505452665))],
#  [(np.int64(0), np.float64(-0.5989979564278806)),
#   (np.int64(1), np.float64(0.27274823832478595))],
#  [(np.int64(0), np.float64(-2.1428587058868693)),
#   (np.int64(1), np.float64(-0.2794346117179693))],
#  [(np.int64(0), np.float64(-0.8497030994700777)),
#   (np.int64(1), np.float64(-0.04114916770661086))],
#  [(np.int64(0), np.float64(-1.6925869264112936)),
#   (np.int64(1), np.float64(-0.5082058490120217))],
#  [(np.int64(0), np.float64(-0.8154331371361152)),
#   (np.int64(1), np.float64(0.5089229630048631))],
#  [(np.int64(0), np.float64(-1.2107650546380384)),
#   (np.int64(1), np.float64(0.016880628903828073))],
#  [(np.int64(0), np.float64(-0.27339950188329826)),
#   (np.int64(1), np.float64(-0.1030889137080218))],
#  [(np.int64(0), np.float64(-13.17412201149047)),
#   (np.int64(1), np.float64(-3.3168300321953677))],
#  [(np.int64(0), np.float64(-0.795678246626225)),
#   (np.int64(1), np.float64(0.3946869355387005))],
#  [(np.int64(0), np.float64(-0.29341879546048305)),
#   (np.int64(1), np.float64(0.38023880306671337))],
#  [(np.int64(0), np.float64(-5.705013512726935)),
#   (np.int64(1), np.float64(-2.248439158220939))],
#  [(np.int64(0), np.float64(-2.015093539436458)),
#   (np.int64(1), np.float64(0.42206056081596055))],
#  [(np.int64(0), np.float64(-0.9266950493115307)),
#   (np.int64(1), np.float64(0.5493035657830254))],
#  [(np.int64(0), np.float64(-1.3409568760842965)),
#   (np.int64(1), np.float64(-0.6734402183504555))],
#  [(np.int64(0), np.float64(-22.6997773045231)),
#   (np.int64(1), np.float64(27.403515219804042))],
#  [(np.int64(0), np.float64(-0.9739964146795697)),
#   (np.int64(1), np.float64(0.26485921002411644))],
#  [(np.int64(0), np.float64(-0.1309392443953902)),
#   (np.int64(1), np.float64(-0.1566413695511552))],
#  [(np.int64(0), np.float64(-4.061062808039044)),
#   (np.int64(1), np.float64(-2.0337741217829617))],
#  [(np.int64(0), np.float64(-0.5358457797994478)),
#   (np.int64(1), np.float64(-0.3897112265996758))],
#  [(np.int64(0), np.float64(-2.3035178828128835)),
#   (np.int64(1), np.float64(0.1680776101394065))],
#  [(np.int64(0), np.float64(-0.763909777530311)),
#   (np.int64(1), np.float64(-0.2511488500683904))],
#  [(np.int64(0), np.float64(-1.3460315192553851)),
#   (np.int64(1), np.float64(0.05946375201641239))],
#  [(np.int64(0), np.float64(-0.6985748890698569)),
#   (np.int64(1), np.float64(-0.36812670079))],
#  [(np.int64(0), np.float64(-1.1009648467934743)),
#   (np.int64(1), np.float64(0.8284311011899103))],
#  [(np.int64(0), np.float64(-0.876724894218799)),
#   (np.int64(1), np.float64(1.7219526880768519))],
#  [(np.int64(0), np.float64(-0.6780595460924539)),
#   (np.int64(1), np.float64(0.20187100297583388))],
#  [(np.int64(0), np.float64(-3.9150418729619223)),
#   (np.int64(1), np.float64(1.618846481977908))],
#  [(np.int64(0), np.float64(-0.4226473850618606)),
#   (np.int64(1), np.float64(0.12843758507172526))],
#  [(np.int64(0), np.float64(-1.5742691855551285)),
#   (np.int64(1), np.float64(-0.6880108518652183))],
#  [(np.int64(0), np.float64(-1.2352709748510602)),
#   (np.int64(1), np.float64(-0.4228972633244466))],
#  [(np.int64(0), np.float64(-2.051026745384331)),
#   (np.int64(1), np.float64(-1.270864127885772))],
#  [(np.int64(0), np.float64(-0.7361579516500466)),
#   (np.int64(1), np.float64(-0.029974401241517276))],
#  [(np.int64(0), np.float64(-0.6429638199654581)),
#   (np.int64(1), np.float64(0.8946862599964239))],
#  [(np.int64(0), np.float64(-0.4746380681161254)),
#   (np.int64(1), np.float64(0.09430646850479717))],
#  [(np.int64(0), np.float64(-0.37128257066592923)),
#   (np.int64(1), np.float64(0.308686406078675))],
#  [(np.int64(0), np.float64(-3.74771562910994)),
#   (np.int64(1), np.float64(-1.7975408837604527))],
#  [(np.int64(0), np.float64(-0.254084373225719)),
#   (np.int64(1), np.float64(-0.06059768096576611))],
#  [(np.int64(0), np.float64(-0.9133385214717646)),
#   (np.int64(1), np.float64(0.4193015745212974))],
#  [(np.int64(0), np.float64(-0.8745210299428235)),
#   (np.int64(1), np.float64(-0.05075759597558767))],
#  [(np.int64(0), np.float64(-3.131349647451543)),
#   (np.int64(1), np.float64(-1.8374691806913244))],
#  [(np.int64(0), np.float64(-1.2036625977731217)),
#   (np.int64(1), np.float64(-0.4158913266683644))],
#  [(np.int64(0), np.float64(-1.3322704172274158)),
#   (np.int64(1), np.float64(0.08454420818617353))],
#  [(np.int64(0), np.float64(-1.3602324418944416)),
#   (np.int64(1), np.float64(-0.045145716073137485))],
#  [(np.int64(0), np.float64(-0.5087858031299644)),
#   (np.int64(1), np.float64(0.6494132097219475))],
#  [(np.int64(0), np.float64(-50.56785980283076)),
#   (np.int64(1), np.float64(-26.910985897242515))],
#  [(np.int64(0), np.float64(-0.14350747224725438)),
#   (np.int64(1), np.float64(-0.08599797640668604))],
# ...
#  [(np.int64(0), np.float64(-0.9430945093200804)),
#   (np.int64(1), np.float64(0.6582875610575297))],
#  [(np.int64(0), np.float64(-0.5307707787255426)),
#   (np.int64(1), np.float64(0.6945003226232521))],
#  [(np.int64(0), np.float64(-2.5461587181234853)),
#   (np.int64(1), np.float64(-1.392106324876406))],
#  [(np.int64(0), np.float64(-0.019510523942150363)),
#   (np.int64(1), np.float64(0.032933845927269674))],
#  [(np.int64(0), np.float64(-0.8057101815288139)),
#   (np.int64(1), np.float64(-0.17992941377653413))],
#  [(np.int64(0), np.float64(-2.3294930503025473)),
#   (np.int64(1), np.float64(-0.8334009233335838))],
#  [],
#  [(np.int64(0), np.float64(-0.6914843910160633)),
#   (np.int64(1), np.float64(-0.34475472973708826))],
#  [(np.int64(0), np.float64(-13.594710614671289)),
#   (np.int64(1), np.float64(-1.9698728941168246))],
#  [(np.int64(0), np.float64(-0.8278447430840599)),
#   (np.int64(1), np.float64(-0.6267637876843806))],
#  [(np.int64(0), np.float64(-1.256202668543261)),
#   (np.int64(1), np.float64(0.7739410442041867))],
#  [(np.int64(0), np.float64(-0.7603505460635426)),
#   (np.int64(1), np.float64(0.46222791155209647))],
#  [(np.int64(0), np.float64(-1.1448918534141994)),
#   (np.int64(1), np.float64(0.000932054287669206))],
#  [(np.int64(0), np.float64(-3.8908236421031686)),
#   (np.int64(1), np.float64(-2.2042499373549904))],
#  [(np.int64(0), np.float64(-0.5342328790546256)),
#   (np.int64(1), np.float64(0.4561169678616461))],
#  [(np.int64(0), np.float64(-0.2712575794903761)),
#   (np.int64(1), np.float64(-0.07308282797088314))],
#  [(np.int64(0), np.float64(-0.9123631113670834)),
#   (np.int64(1), np.float64(0.7498162419558153))],
#  [(np.int64(0), np.float64(-0.015201062564506892)),
#   (np.int64(1), np.float64(-0.01534971586549838))],
#  [(np.int64(0), np.float64(-0.6428179526311213)),
#   (np.int64(1), np.float64(-0.39867783142718155))],
#  [(np.int64(0), np.float64(-0.3705970089204508)),
#   (np.int64(1), np.float64(-0.07231351173994983))],
#  [(np.int64(0), np.float64(-1.0533370446346522)),
#   (np.int64(1), np.float64(-0.013525572590218306))],
#  [(np.int64(0), np.float64(-0.07881886128522302)),
#   (np.int64(1), np.float64(0.16733874395006745))],
#  [(np.int64(0), np.float64(-3.561767372604401)),
#   (np.int64(1), np.float64(2.9364357138659716))],
#  [(np.int64(0), np.float64(-2.0585351761004094)),
#   (np.int64(1), np.float64(-0.4215623100744648))],
#  [(np.int64(0), np.float64(-3.9174474980954415)),
#   (np.int64(1), np.float64(0.33922899727920064))],
#  [(np.int64(0), np.float64(-2.6452316519569483)),
#   (np.int64(1), np.float64(-2.2421703680449188))],
#  [(np.int64(0), np.float64(-0.6271749215769723)),
#   (np.int64(1), np.float64(0.6246892028938689))],
#  [(np.int64(0), np.float64(-2.6086732445571927)),
#   (np.int64(1), np.float64(0.4763264742640972))],
#  [(np.int64(0), np.float64(-0.5959975696221751)),
#   (np.int64(1), np.float64(-0.12645583999323262))],
#  [(np.int64(0), np.float64(-4.511046541172618)),
#   (np.int64(1), np.float64(0.16460677399782475))],
#  [(np.int64(0), np.float64(-2.5325383005705837)),
#   (np.int64(1), np.float64(1.381217970163898))],
#  [(np.int64(0), np.float64(-0.12824579642617356)),
#   (np.int64(1), np.float64(0.09948866987675577))],
#  [(np.int64(0), np.float64(-0.6643450977124876)),
#   (np.int64(1), np.float64(-0.04990638682509759))],
#  [(np.int64(0), np.float64(-2.4705695937973906)),
#   (np.int64(1), np.float64(0.39565359422035057))],
#  [(np.int64(0), np.float64(-1.5537148003244101)),
#   (np.int64(1), np.float64(0.5478414530160584))],
#  [(np.int64(0), np.float64(-4.27358864328916)),
#   (np.int64(1), np.float64(2.517614474312064))],
#  [(np.int64(0), np.float64(-1.8204091420995052)),
#   (np.int64(1), np.float64(-0.4202980678623693))],
#  [(np.int64(0), np.float64(-0.7383057116986665)),
#   (np.int64(1), np.float64(-0.0939979051522926))],
#  [(np.int64(0), np.float64(-0.46837866391571625)),
#   (np.int64(1), np.float64(0.13524460606535063))],
#  [(np.int64(0), np.float64(-0.33279916826915484)),
#   (np.int64(1), np.float64(0.12026049259764464))],
#  [(np.int64(0), np.float64(-1.6707160269508878)),
#   (np.int64(1), np.float64(1.8217650921027488))],
#  [(np.int64(0), np.float64(-2.6901621588053493)),
#   (np.int64(1), np.float64(-1.1436108677315182))],
#  [(np.int64(0), np.float64(-1.0373780652200228)),
#   (np.int64(1), np.float64(1.104487352290752))],
#  [(np.int64(0), np.float64(-0.6459862636568117)),
#   (np.int64(1), np.float64(-0.3475141939545195))],
#  [(np.int64(0), np.float64(-1.0458417610131374)),
#   (np.int64(1), np.float64(-0.5122804571370368))],
#  [(np.int64(0), np.float64(-1.1705922255326298)),
#   (np.int64(1), np.float64(1.3183755452695776))],
#  [(np.int64(0), np.float64(-0.8571971688945961)),
#   (np.int64(1), np.float64(0.5387606275504918))],
#  [(np.int64(0), np.float64(-0.47317267515083045)),
#   (np.int64(1), np.float64(0.43718167678264563))],
#  [(np.int64(0), np.float64(-2.1932156388734323)),
#   (np.int64(1), np.float64(-1.3602451997608533))],
#  [(np.int64(0), np.float64(-2.045313402581705)),
#   (np.int64(1), np.float64(-0.3531564524229823))],
#  [(np.int64(0), np.float64(-1.6964203028117264)),
#   (np.int64(1), np.float64(1.3965123062757192))],
#  [(np.int64(0), np.float64(-1.211475837299482)),
#   (np.int64(1), np.float64(1.3715801885117616))],
#  [(np.int64(0), np.float64(-1.6255201508881514)),
#   (np.int64(1), np.float64(0.4011152309846766))],
#  [(np.int64(0), np.float64(-0.3259056272740107)),
#   (np.int64(1), np.float64(0.26402409857440484))],
#  [(np.int64(0), np.float64(-2.0452461576433807)),
#   (np.int64(1), np.float64(-0.09211576847265161))],
#  [(np.int64(0), np.float64(-0.1535354994320999)),
#   (np.int64(1), np.float64(0.026112209949699296))],
#  [(np.int64(0), np.float64(-4.179565208684492)),
#   (np.int64(1), np.float64(-0.33057447304562365))],
#  [(np.int64(0), np.float64(-0.522122573595913)),
#   (np.int64(1), np.float64(-0.19757867146144176))],
#  [(np.int64(0), np.float64(-0.6867464828685977)),
#   (np.int64(1), np.float64(0.43348798125984594))],
#  [(np.int64(0), np.float64(-1.8481557432760696)),
#   (np.int64(1), np.float64(-0.17760390697011294))],
#  [(np.int64(0), np.float64(-0.62185496495357)),
#   (np.int64(1), np.float64(0.5271813432160279))],
#  [(np.int64(0), np.float64(-1.071739345908303)),
#   (np.int64(1), np.float64(1.1573912902750132))],
#  [(np.int64(0), np.float64(-1.7448614480832103)),
#   (np.int64(1), np.float64(-0.13678937966613683))],
#  [(np.int64(0), np.float64(-4.855266135097408)),
#   (np.int64(1), np.float64(-1.434542263236467))],
#  [(np.int64(0), np.float64(-0.2459411592430257)),
#   (np.int64(1), np.float64(-0.3831581501070977))],
#  [(np.int64(0), np.float64(-1.2286772939357513)),
#   (np.int64(1), np.float64(-0.9203214821691702))],
#  [(np.int64(0), np.float64(-0.700292558528347)),
#   (np.int64(1), np.float64(0.4254675334695656))],
#  [(np.int64(0), np.float64(-1.3667179362555)),
#   (np.int64(1), np.float64(-0.30752380070000457))],
#  [(np.int64(0), np.float64(-0.9771185444081154)),
#   (np.int64(1), np.float64(-0.06955600182573662))],
#  [(np.int64(0), np.float64(-1.0072781019601385)),
#   (np.int64(1), np.float64(-0.6514772439175425))],
#  [(np.int64(0), np.float64(-2.003469104018949)),
#   (np.int64(1), np.float64(0.07039717917793206))],
#  [(np.int64(0), np.float64(-8.916280041791092)),
#   (np.int64(1), np.float64(-3.2545635971699154))],
#  [(np.int64(0), np.float64(-23.317771095924382)),
#   (np.int64(1), np.float64(-8.176410335995962))],
#  [(np.int64(0), np.float64(-2.9684652574733783)),
#   (np.int64(1), np.float64(-0.15127280420530767))],
#  [(np.int64(0), np.float64(-2.4439919935194783)),
#   (np.int64(1), np.float64(-1.13713255365731))],
#  [(np.int64(0), np.float64(-1.374861514747521)),
#   (np.int64(1), np.float64(-0.5243738655553973))],
#  [(np.int64(0), np.float64(-2.1836707743354657)),
#   (np.int64(1), np.float64(2.440585545168079))],
#  [(np.int64(0), np.float64(-11.020073674067257)),
#   (np.int64(1), np.float64(-2.9642496988537324))],
#  [(np.int64(0), np.float64(-2.5216766630830385)),
#   (np.int64(1), np.float64(-1.0923758169919593))],
#  [(np.int64(0), np.float64(-1.632545922575295)),
#   (np.int64(1), np.float64(1.531096949667608))],
#  [(np.int64(0), np.float64(-1.2887748432532162)),
#   (np.int64(1), np.float64(0.4700015923565046))],
#  [(np.int64(0), np.float64(-1.6533893901329142)),
#   (np.int64(1), np.float64(-1.5137468176168098))],
#  [(np.int64(0), np.float64(-0.804429781045292)),
#   (np.int64(1), np.float64(0.2175755138130281))],
#  [(np.int64(0), np.float64(-0.27872951704529086)),
#   (np.int64(1), np.float64(-0.11640258351544122))],
#  [(np.int64(0), np.float64(-0.6575991130191835)),
#   (np.int64(1), np.float64(-0.34714258491996425))],
#  [(np.int64(0), np.float64(-0.6182937315940602)),
#   (np.int64(1), np.float64(0.259677457656061))],
#  [(np.int64(0), np.float64(-0.3673122453405299)),
#   (np.int64(1), np.float64(-0.1042496215747087))],
#  [(np.int64(0), np.float64(-0.5263120720409198)),
#   (np.int64(1), np.float64(-0.21940874787545162))],
#  [(np.int64(0), np.float64(-0.5102076859892921)),
#   (np.int64(1), np.float64(0.7854994491519562))],
#  [(np.int64(0), np.float64(-0.27826815469546134)),
#   (np.int64(1), np.float64(0.17420619643769256))],
#  [(np.int64(0), np.float64(-3.8748502769945388)),
#   (np.int64(1), np.float64(-3.2150131085041824))],
#  [(np.int64(0), np.float64(-0.0818571982093848)),
#   (np.int64(1), np.float64(-0.026893282375222385))],
#  [(np.int64(0), np.float64(-1.5045887851577835)),
#   (np.int64(1), np.float64(0.002464133681547924))],
#  [(np.int64(0), np.float64(-1.2670830181582442)),
#   (np.int64(1), np.float64(-0.2050226993819464))],
#  [(np.int64(0), np.float64(-0.6822668090650441)),
#   (np.int64(1), np.float64(-0.0473446049273111))],
#  [(np.int64(0), np.float64(-0.9206722047579645)),
#   (np.int64(1), np.float64(0.21423869434852122))],
#  [(np.int64(0), np.float64(-2.695884915313729)),
#   (np.int64(1), np.float64(-1.8133550473907885))],
#  [(np.int64(0), np.float64(-0.9301075635861428)),
#   (np.int64(1), np.float64(0.6817343171643422))],
#  [(np.int64(0), np.float64(-2.1659443027999785)),
#   (np.int64(1), np.float64(-0.42331982728168427))],
#  [(np.int64(0), np.float64(-7.948297454893317)),
#   (np.int64(1), np.float64(-2.0224277616935242))],
#  [(np.int64(0), np.float64(-0.71506103606429)),
#   (np.int64(1), np.float64(0.29530219696897136))],
#  [(np.int64(0), np.float64(-0.25204266209861986)),
#   (np.int64(1), np.float64(0.039763501236902137))],
#  [(np.int64(0), np.float64(-0.22467785947294555)),
#   (np.int64(1), np.float64(0.05800224953507312))],
#  [(np.int64(0), np.float64(-0.0637803064756133)),
#   (np.int64(1), np.float64(0.006577663046463229))],
#  [(np.int64(0), np.float64(-0.9928583127898609)),
#   (np.int64(1), np.float64(0.00591124294001345))],
#  [(np.int64(0), np.float64(-0.34840199258598453)),
#   (np.int64(1), np.float64(-0.09104359589882187))],
#  [(np.int64(0), np.float64(-2.2604133159653474)),
#   (np.int64(1), np.float64(-0.19452499056716396))],
#  [(np.int64(0), np.float64(-0.6749277526344515)),
#   (np.int64(1), np.float64(0.146389453648639))],
#  [(np.int64(0), np.float64(-1.4077952428750422)),
#   (np.int64(1), np.float64(0.5124628192971672))],
#  [(np.int64(0), np.float64(-2.6322880720760438)),
#   (np.int64(1), np.float64(-2.7326684978392968))],
#  [(np.int64(0), np.float64(-11.113610730058156)),
#   (np.int64(1), np.float64(4.638387053977095))],
#  [(np.int64(0), np.float64(-0.08540104170813867)),
#   (np.int64(1), np.float64(-0.013118334249715174))],
#  [(np.int64(0), np.float64(-0.36870019281805555)),
#   (np.int64(1), np.float64(0.23030113472799146))],
#  [(np.int64(0), np.float64(-5.927029004905514)),
#   (np.int64(1), np.float64(0.7511178905968962))],
#  [(np.int64(0), np.float64(-1.1950713842899454)),
#   (np.int64(1), np.float64(1.1441822989942012))],
#  [(np.int64(0), np.float64(-1.483416762067262)),
#   (np.int64(1), np.float64(0.09480919404629086))],
#  [(np.int64(0), np.float64(-1.472135087229612)),
#   (np.int64(1), np.float64(-0.5517811084853375))],
#  [(np.int64(0), np.float64(-1.159615950133175)),
#   (np.int64(1), np.float64(-0.5111491809249873))],
#  [(np.int64(0), np.float64(-4.036687147914847)),
#   (np.int64(1), np.float64(-2.3173283521596963))],
#  [(np.int64(0), np.float64(-0.21804731527429932)),
#   (np.int64(1), np.float64(-0.055913965714139535))],
#  [(np.int64(0), np.float64(-3.8837610198463137)),
#   (np.int64(1), np.float64(0.07733513340774838))],
#  [(np.int64(0), np.float64(-2.6623543665130374)),
#   (np.int64(1), np.float64(-1.0692207647750391))],
#  [(np.int64(0), np.float64(-2.7262408982703805)),
#   (np.int64(1), np.float64(-0.008172564383353592))],
#  [(np.int64(0), np.float64(-0.5341096545928777)),
#   (np.int64(1), np.float64(-0.5475636191912305))],
#  [(np.int64(0), np.float64(-3.8166242731977285)),
#   (np.int64(1), np.float64(-0.6962290488299342))],
#  [(np.int64(0), np.float64(-0.2954956588892524)),
#   (np.int64(1), np.float64(-0.033118110582617245))],
#  [(np.int64(0), np.float64(-0.7046520295218119)),
#   (np.int64(1), np.float64(-0.1493468897178421))],
#  [(np.int64(0), np.float64(-2.4466942911504055)),
#   (np.int64(1), np.float64(-1.9284279875307695))],
#  [(np.int64(0), np.float64(-2.3648175179608524)),
#   (np.int64(1), np.float64(0.4638147587122649))],
#  [(np.int64(0), np.float64(-0.4484504053997786)),
#   (np.int64(1), np.float64(0.17115673796840597))],
#  [(np.int64(0), np.float64(-1.5080060495984087)),
#   (np.int64(1), np.float64(1.7243814623757572))],
#  [(np.int64(0), np.float64(-0.7709511871914555)),
#   (np.int64(1), np.float64(0.6475135456968348))],
#  [(np.int64(0), np.float64(-0.9568888214799505)),
#   (np.int64(1), np.float64(0.2517907598205888))],
#  [(np.int64(0), np.float64(-2.6168454637428367)),
#   (np.int64(1), np.float64(0.6680627054321912))],
#  [(np.int64(0), np.float64(-0.735774881859899)),
#   (np.int64(1), np.float64(-0.3969435279779388))],
#  [(np.int64(0), np.float64(-4.587883105276491)),
#   (np.int64(1), np.float64(-2.5283766158544703))],
#  [(np.int64(0), np.float64(-1.3907454031024904)),
#   (np.int64(1), np.float64(0.34672609114800784))],
#  [(np.int64(0), np.float64(-0.5846267038618326)),
#   (np.int64(1), np.float64(0.7281129597635865))],
#  [(np.int64(0), np.float64(-1.3649887653818344)),
#   (np.int64(1), np.float64(-0.8519652910791281))],
#  [(np.int64(0), np.float64(-0.7877099297008797)),
#   (np.int64(1), np.float64(-0.1080681491690963))],
#  [(np.int64(0), np.float64(-1.4787961626108956)),
#   (np.int64(1), np.float64(-0.31002744228368173))],
#  [(np.int64(0), np.float64(-0.47484625994433083)),
#   (np.int64(1), np.float64(0.02529925785763782))],
#  [(np.int64(0), np.float64(-0.5495498239708796)),
#   (np.int64(1), np.float64(0.2097778156831803))],
#  [(np.int64(0), np.float64(-0.5943095497371808)),
#   (np.int64(1), np.float64(0.45291645744607))],
#  [(np.int64(0), np.float64(-0.24789138995143178)),
#   (np.int64(1), np.float64(-0.11378874561901388))],
#  [(np.int64(0), np.float64(-0.5436622350986213)),
#   (np.int64(1), np.float64(-0.07021907683201789))],
#  [(np.int64(0), np.float64(-0.43941080591388615)),
#   (np.int64(1), np.float64(0.5172983592473559))],
#  [(np.int64(0), np.float64(-1.951260096200309)),
#   (np.int64(1), np.float64(-0.46865045839952724))],
#  [(np.int64(0), np.float64(-1.4965821122837923)),
#   (np.int64(1), np.float64(-0.3105869618096737))],
#  [(np.int64(0), np.float64(-0.7297645746447896)),
#   (np.int64(1), np.float64(0.24328338764181295))],
#  [(np.int64(0), np.float64(-0.002463735816556899)),
#   (np.int64(1), np.float64(0.002937791764470562))],
#  [(np.int64(0), np.float64(-4.009084878401231)),
#   (np.int64(1), np.float64(-0.6857319351336679))],
#  [(np.int64(0), np.float64(-1.1250344638292276)),
#   (np.int64(1), np.float64(-0.4519015645762688))],
#  [(np.int64(0), np.float64(-1.1922166592580683)),
#   (np.int64(1), np.float64(1.044884659699545))],
#  [(np.int64(0), np.float64(-1.7826464179952253)),
#   (np.int64(1), np.float64(-0.30457489792686926))],
#  [(np.int64(0), np.float64(-0.9081313325107663)),
#   (np.int64(1), np.float64(-0.04468936402564512))],
#  [(np.int64(0), np.float64(-87.50273156328092)),
#   (np.int64(1), np.float64(93.55719983283639))]]
# 문서별 토픽 할당값의 행렬 표현:
# array([[-2.8400e-01,  7.3000e-01],
#        [-1.5390e+00, -7.4000e-02],
#        [-4.9700e-01,  5.4500e-01],
#        ...,
#        [-1.7830e+00, -3.0500e-01],
#        [-9.0800e-01, -4.5000e-02],
#        [-8.7503e+01,  9.3557e+01]])

# %%
print("첫번째 문서의 토픽 할당값", doc_topic_assignment_mat[0,:])
# Out:
# 첫번째 문서의 토픽 할당값 [-0.28369168  0.72995173]

# %% [markdown]
# * 절댓값이 두번째 토픽이 더 크므로 두번째 토픽의 영향력이 큼

# %% [markdown]
# ### 6. 토픽별 코퍼스 내 중요도 정보

# %%
singular_values = lsi_model.projection.s
print("토픽별 코퍼스 내 중요도(특이값):", singular_values)
# Out:
# 토픽별 코퍼스 내 중요도(특이값): [5.41820867 3.50596508]

# %%
print("첫 번째 토픽의 특이값:", singular_values[0])
# Out:
# 첫 번째 토픽의 특이값: 5.418208665521935

# %% [markdown]
# * 첫번째 토픽이 두번째 토픽보다 코퍼스 내에서 더 중요(첫번째 토픽이 문서들의 주요 패턴을 더 잘 포착한다고 볼 수 있음)
